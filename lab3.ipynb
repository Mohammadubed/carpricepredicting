# %%
Skills Network Logo

Exploratory Data Analysis
Estimated time needed: 30 minutes

Objectives
After completing this lab you will be able to:

Explore features or characteristics to predict price of car
Analyze patterns and run descriptive statistical analysis
Group data based on identified parameters and create pivot tables
Identify the effect of independent attributes on price of cars
# Out:
#   Cell In[1], line 1
#     Skills Network Logo
#            ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
file_path= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv"
dataframe = pd.read_csv(file_path, header = 0)

# %%
dataframe.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
import matplotlib.pyplot as plot 
# %matplotlib inline

# %%
print(dataframe.dtypes)
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
numericframe = dataframe.apply(pd.to_numeric , errors = "coerce")
numericframe.corr()
# Out:
#                    symboling  normalized-losses  make  aspiration  \
# symboling           1.000000           0.466264   NaN         NaN
# normalized-losses   0.466264           1.000000   NaN         NaN
# make                     NaN                NaN   NaN         NaN
# aspiration               NaN                NaN   NaN         NaN
# num-of-doors             NaN                NaN   NaN         NaN
# body-style               NaN                NaN   NaN         NaN
# drive-wheels             NaN                NaN   NaN         NaN
# engine-location          NaN                NaN   NaN         NaN
# wheel-base         -0.535987          -0.056661   NaN         NaN
# length             -0.365404           0.019424   NaN         NaN
# width              -0.242423           0.086802   NaN         NaN
# height             -0.550160          -0.373737   NaN         NaN
# curb-weight        -0.233118           0.099404   NaN         NaN
# ...

# %%
dataframe[["horsepower","price"]].corr()
# Out:
#             horsepower     price
# horsepower    1.000000  0.809575
# price         0.809575  1.000000

# %%
sns.regplot(x = "engine-size", y = "price", data = dataframe )
plot.ylim(0,)
# Out:
# (0.0, 53378.59899787979)

# %%
dataframe[["engine-size", "price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
sns.regplot(x = "highway-mpg", y = "price" , data = dataframe)
# Out:
# <Axes: xlabel='highway-mpg', ylabel='price'>

# %%
dataframe[['highway-mpg', 'price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %%
sns.regplot(x = "peak-rpm" , y = "price" , data = dataframe)
# Out:
# <Axes: xlabel='peak-rpm', ylabel='price'>

# %%
dataframe[["peak-rpm","price"]].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %%
sns.regplot(x = "stroke" , y = "price" , data = dataframe)
dataframe[["stroke","price"]].corr()
# Out:
#          stroke    price
# stroke  1.00000  0.08231
# price   0.08231  1.00000

# %%
sns.boxplot(x = "body-style", y = "price", data = dataframe)
# Out:
# <Axes: xlabel='body-style', ylabel='price'>

# %%
sns.boxplot(x = "engine-location", y = "price" , data = dataframe)
# Out:
# <Axes: xlabel='engine-location', ylabel='price'>

# %%
sns.boxplot(x = "drive-wheels", y = "price" , data = dataframe)
# Out:
# <Axes: xlabel='drive-wheels', ylabel='price'>

# %%
dataframe.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %%
dataframe.describe(include = "object")
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %%
sns.boxplot(x = "num-of-doors", y = "price" , data = dataframe)
# Out:
# <Axes: xlabel='num-of-doors', ylabel='price'>

# %%
drivewheels = dataframe['drive-wheels'].value_counts().to_frame()

# %%
drivewheels.reset_index(inplace = True)
drivewheels = drivewheels.rename(columns = {"drive-wheels":"value_counts"})

# %%
drivewheels.index.name = "drive-wheels"
drivewheels.head()
# Out:
#              value_counts  count
# drive-wheels
# 0                     fwd    118
# 1                     rwd     75
# 2                     4wd      8

# %%
enginelocation = dataframe['engine-location'].value_counts().to_frame()
enginelocation.reset_index(inplace = True)
enginelocation = enginelocation.rename(columns = {"engine-location":"value_counts"})
enginelocation.index.name = 'engine-location'
enginelocation.head()
# Out:
#                 value_counts  count
# engine-location
# 0                      front    198
# 1                       rear      3

# %%
dataframe['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
groupframe = dataframe[['drive-wheels','body-style','price']]
groupframe.head()
# Out:
#   drive-wheels   body-style    price
# 0          rwd  convertible  13495.0
# 1          rwd  convertible  16500.0
# 2          rwd    hatchback  16500.0
# 3          fwd        sedan  13950.0
# 4          4wd        sedan  17450.0

# %%
dw_gframe = groupframe.groupby(['drive-wheels'] , as_index = False).agg({'price':'mean'})
dw_gframe.head()
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %%
dw_bs_gframe = groupframe.groupby(['drive-wheels','body-style'] , as_index = False).mean()
dw_bs_gframe.head()
# Out:
#   drive-wheels   body-style         price
# 0          4wd    hatchback   7603.000000
# 1          4wd        sedan  12647.333333
# 2          4wd        wagon   9095.750000
# 3          fwd  convertible  11595.000000
# 4          fwd      hardtop   8249.000000

# %%
dw_bs_pframe = dw_bs_gframe.pivot(index = "drive-wheels" , columns = "body-style").fillna(0)
dw_bs_pframe.reset_index()
# Out:
#            drive-wheels       price                                            \
# body-style              convertible       hardtop     hatchback         sedan
# 0                   4wd         0.0      0.000000   7603.000000  12647.333333
# 1                   fwd     11595.0   8249.000000   8396.387755   9811.800000
# 2                   rwd     23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style         wagon
# 0            9095.750000
# 1            9997.333333
# 2           16994.222222

# %%
dw_bs_pframe.head()
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
bs_gframe = groupframe.groupby(['body-style'], as_index=False).agg({'price':'mean'})
bs_gframe.head()
# Out:
#     body-style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9957.441176
# 3        sedan  14459.755319
# 4        wagon  12371.960000

# %%
import matplotlib.pyplot as plot

# %%
plot.pcolor(dw_bs_pframe, cmap = 'RdBu')
plot.xlabel("Body-Style")
plot.ylabel("Drive-Wheels")
plot.colorbar()
plot.show()

# %%
dw_bs_pframe.head()
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
fig , ax = plot.subplots()
hmap = ax.pcolor(dw_bs_pframe , cmap = 'RdBu')
row_labels = dw_bs_pframe.columns.levels[1]
col_labels = dw_bs_pframe.index

ax.set_xticks(np.arange(dw_bs_pframe.shape[1])+0.5 , minor = False)
ax.set_yticks(np.arange(dw_bs_pframe.shape[0])+0.5 , minor = False)
ax.set_xticklabels(row_labels , minor = False)
ax.set_yticklabels(col_labels , minor = False)

plot.xticks(rotation = 90)
fig.colorbar(hmap)
plot.show()

# %%
from scipy import stats

# %%
def printpearson(x):
    pearson_cof , pval = stats.pearsonr(dataframe[x] , dataframe['price'])
    print(pearson_cof , pval)

# %%
printpearson('wheel-base')
# Out:
# 0.5846418222655081 8.076488270732847e-20

# %%
printpearson('horsepower')
# Out:
# 0.809574567003656 6.369057428259638e-48

# %%
printpearson('length')
# Out:
# 0.690628380448364 8.016477466158899e-30

# %%
printpearson('width')
# Out:
# 0.7512653440522674 9.200335510481227e-38

# %%
printpearson('curb-weight')
# Out:
# 0.8344145257702845 2.189577238893924e-53

# %%
printpearson('engine-size')
# Out:
# 0.8723351674455185 9.26549162219869e-64

# %%
printpearson('bore')
# Out:
# 0.5431553832626603 8.049189483935274e-17

# %%
printpearson('city-mpg')
# Out:
# -0.6865710067844679 2.3211320655675065e-29

# %%
printpearson('highway-mpg')
# Out:
# -0.7046922650589529 1.7495471144476634e-31

# %%
Conclusion: Important Variables
We now have a better idea of what our data looks like and which variables are important to take into account when predicting the car price. We have narrowed it down to the following variables:

Continuous numerical variables:

Length
Width
Curb-weight
Engine-size
Horsepower
City-mpg
Highway-mpg
Wheel-base
Bore
Categorical variables:

Drive-wheels
As we now move into building machine learning models to automate our analysis, feeding the model with variables that meaningfully affect our target variable will improve our model's prediction performance.
